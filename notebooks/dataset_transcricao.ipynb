# %% [markdown]
# ### **Importar e limpar Dataset**

# %%
import pandas as pd

# %%
# Importar dataset
df = pd.read_csv('raw_data/validated.tsv', sep='\t')
# Out:
# /tmp/ipykernel_2451/975782715.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('raw_data/validated.tsv', sep='\t')

# %%
#Selecionar colunas para uso
df_clean = df[['sentence_id','path','sentence', 'gender','variant', 'age', 'accents']]

# %%
#Selecionar apenas os aúdios em Português (Brasil)
df_usable = df_clean[df_clean['variant'] == 'Portuguese (Brasil)'].dropna().reset_index().drop(columns=['index'])

# %%
#Adicionar uma coluna com a contagem de caracteres do áudio para selecionar apenas os 50 maiores
df_usable['count_caracteres'] = df_usable['sentence'].str.len()

# %%
#Disponibilzar a sentença inteira do áudio para leitura
pd.set_option('display.max_colwidth', None)
a = df_usable[df_usable['path'] == 'common_voice_pt_32804409.mp3']
a['sentence']
# Out:
# 7359    Meu nome está nas manchetes”, disse o velho.\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804420.mp3\teb8a2331547b204c4a5cfac5d1ce4b0bc505bf839558cee5725e5d80c33356ed\tLagoa da Confusão\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804422.mp3\te4186a28d767a46d5b2d35e5906cfe395c908f234495912f67dcc44655bf546e\tEu andei por mais de duas horas depois de ouvir o guia de áudio.\t\t6\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804423.mp3\td68e5ccbbf0f57d13a1e94604dfce4ceac9e2554f4ecf742e2f780b9e385f978\tCabeceiras\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804424.mp3\tf4c2b7554a8437b79eec6f92fd1414e7936681094c54dcd989c1c201a8bb8cbf\tEncomende a lua em uma enseada.\t\t4\t2\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804435.mp3\tf75443c8d5a521e18d031bd87f1626602091165e2ef4e920889ad4f0c4001306\tEnganando os pobres\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804436.mp3\te886afde6083fbce235b84acf185bee5161704ba5652ffb5c452d068f02abe7e\tPorto Vera Cruz\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804437.mp3\td7efb22024acd0b044a645b9381c597e37e2970887cc80fb44cb6d59ee60e6c4\tPão de Açúcar\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804438.mp3\tf685f4a35167ce1966666ce98b6a7d22007e7594eee1c3c215433a4dc6149a95\tPedra Branca\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804439.mp3\tedd92db0e6eb2bdc1d011781467c501f3e81592a6f244c66af3de5159a98ccac\tO que mais posso pedir?\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804465.mp3\te2c37b23afde3d7405b888dcc872cfbc8159a7d08fbac7afd344d3af9284b555\tSanta Maria das Barreiras\t\t2\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804466.mp3\td95486c3bc79b9b2f5b0783d38a997e7e1f1702896794af6899f1c2a27dc719a\tRio Doce\t\t6\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516d878b2fc3b099914b5c7089abec30827a452b7200bc282a7f299f83c780e38371380cef31faf101439a5965b0edd9c0231c4964fda221c96c0bc462fb\tcommon_voice_pt_32804467.mp3\tf784fd79b96674f9381c9cadc3f1d6a69b7984e95469e25df6f0ba7902933e2e\tRedenção da Serra\t\t4\t0\tsixties\tmale_masculine\tPaulistano.\tPortuguese (Brasil)\tpt\t\nf4d2516 ...
# Name: sentence, dtype: object

# %%
#Selecionar 50 aúdios para posterior transcrição e análise
pd.reset_option('display.max_colwidth', None)
lista = ['path', 'sentence', 'count_caracteres']
df_usable[lista].sort_values(by='count_caracteres', ascending=False).head(5)
# Out:
#                                path  \
# 7359   common_voice_pt_32804409.mp3
# 4395   common_voice_pt_34645484.mp3
# 6171   common_voice_pt_35904061.mp3
# 690    common_voice_pt_37591374.mp3
# 19674  common_voice_pt_36872616.mp3
#
#                                                 sentence  count_caracteres
# 7359   Meu nome está nas manchetes”, disse o velho.\t...            328780
# 4395   É um código!”, disse a garota, bem satisfeita\...             26082
# 6171   Meu nome está nas manchetes”, disse o velho.\t...             14463
# 690    actínio, tório, protactínio, urânio, netúnio, ...               134
# 19674  xaroposo, litosfera, crosta terrestre, lúmen, ...               128

# %%
#Baixar o arquivo em csv
#df_usable.to_csv('raw_data/dataset_clean.csv', sep=';', index=True)

# %% [markdown]
# ### **Modelo google speech para transcrição**

# %%
#Instalação de bibliotecas usadas para as análises
# !pip install pydub
# !pip install SpeechRecognition
# !pip install librosa
# !pip install jiwer
# !pip install unidecode
# Out:
# Requirement already satisfied: pydub in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (0.25.1)
# ^C
# Requirement already satisfied: SpeechRecognition in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (3.10.4)
# Requirement already satisfied: requests>=2.26.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from SpeechRecognition) (2.32.2)
# Requirement already satisfied: typing-extensions in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from SpeechRecognition) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Requirement already satisfied: librosa in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (1.13.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (1.5.0)
# Requirement already satisfied: joblib>=0.14 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (0.59.1)
# Requirement already satisfied: soundfile>=0.12.1 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from lazy-loader>=0.1->librosa) (24.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Requirement already satisfied: jiwer in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (3.0.4)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (from jiwer) (3.9.1)
# Requirement already satisfied: unidecode in /home/akira/.pyenv/versions/3.10.6/envs/voice_to_action/lib/python3.10/site-packages (1.3.8)

# %%
import librosa
import librosa.display
import IPython.display as ipd

# %%
#Áudios do dataset
y, sr = librosa.load('/home/akira/code/acbarrosramos/voice_to_action/cv-corpus-17.0-2024-03-15-pt/cv-corpus-17.0-2024-03-15/pt/sample_data/common_voice_pt_37591374.mp3')
ipd.Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Função para transcrição dos áudios do dataset

from pydub import AudioSegment
import speech_recognition as sr
import io
import os

def speech_to_text(audio_file):

    recognizer = sr.Recognizer()

    file_extension = os.path.splitext(audio_file)[1][1:]

    audio_data = AudioSegment.from_file(audio_file, format=file_extension)

    # Converter para WAV e criar um buffer de bytes --preprocessing
    wav_buffer = io.BytesIO()
    audio_data.export(wav_buffer, format="wav")  # Converta para WAV
    wav_buffer.seek(0)

    # Usar BytesIO como entrada para o Recognizer
    with sr.AudioFile(wav_buffer) as source:
        audio_data = recognizer.record(source)

    try:
        text = recognizer.recognize_google(audio_data, language='pt-BR')
        return text

    except sr.UnknownValueError:
        return "Não foi possível entender o áudio"
    except sr.RequestError as e:
        return "Erro ao solicitar reconhecimento de fala; {0}".format(e)


audio_file = "/home/akira/code/acbarrosramos/voice_to_action/cv-corpus-17.0-2024-03-15-pt/cv-corpus-17.0-2024-03-15/pt/sample_data/common_voice_pt_24662841.mp3"
texto_transcrito = speech_to_text(audio_file)
texto_transcrito
# Out:
# 'mãe'

# %%
#Função para transcrever cada um dos 50 arquivos selecionados do dataset

def transcrever_arquivos_na_pasta(pasta):
    transcricoes = []

    for nome_arquivo in os.listdir(pasta):
        caminho_completo = os.path.join(pasta, nome_arquivo)
        if os.path.isfile(caminho_completo) and nome_arquivo.endswith('.mp3'):
            #print(f"Processando arquivo: {nome_arquivo}")
            texto_transcrito = speech_to_text(caminho_completo)
            transcricoes.append({'path': nome_arquivo, 'texto_transcrito_modelo': texto_transcrito})

    df_transcricoes = pd.DataFrame(transcricoes)
    return df_transcricoes

# %% [markdown]
# ### **Merge: Dataframe + transcrições**

# %%
#Dataframe com as transcrições
pasta = '/home/akira/code/acbarrosramos/voice_to_action/cv-corpus-17.0-2024-03-15-pt/cv-corpus-17.0-2024-03-15/pt/sample_data/'

df_transcricoes = transcrever_arquivos_na_pasta(pasta)
df_transcricoes.head(5)
# Out:
#                            path  \
# 0  common_voice_pt_36872065.mp3
# 1  common_voice_pt_36862628.mp3
# 2  common_voice_pt_32172665.mp3
# 3  common_voice_pt_30580984.mp3
# 4  common_voice_pt_36455648.mp3
#
#                              texto_transcrito_modelo
# 0  cabeçote Coligação pantográfico craniano mutuá...
# 1  logaritmo decimal material Longitude meridiano...
# 2  meninas e adolescentes que apresentam necessid...
# 3  trabalhos posteriores foram realizados onde fo...
# 4  trabalhos posteriores foram realizados onde fo...

# %%
#Dataframe para analisar texto transcrito
lista_variaveis = ['path', 'sentence', 'count_caracteres']
df_concat = df_usable[lista_variaveis].merge(df_transcricoes, how='inner', on='path')
df_concat.tail(5)
# Out:
#                             path  \
# 45  common_voice_pt_31750547.mp3
# 46  common_voice_pt_32085492.mp3
# 47  common_voice_pt_32172665.mp3
# 48  common_voice_pt_32258477.mp3
# 49  common_voice_pt_32348921.mp3
#
#                                              sentence  count_caracteres  \
# 45  Compartilhá-los será impossível, pelo menos us...                99
# 46  Todos os dias, empresas e profissionais presta...                98
# 47  meninas e adolescentes que apresentam necessid...               108
# 48                                                Luz                 3
# 49  Selecione produtos para preparar calorias e pr...               110
#
#                               texto_transcrito_modelo
# 45  compartilhar alos será impossível pelo menos u...
# 46  todos os dias empresas e profissionais prestam...
# 47  meninas e adolescentes que apresentam necessid...
# 48                                                luz
# 49  selecione produtos para preparar calorias e pr...

# %% [markdown]
# ### **Validação antes da normalização do modelo com base em WER e CER**

# %%
#Função para validar o modelo de transcrição com base nas palavras e nos caracteres
#Word Error Rate (WER): taxa de acerto das palavras transcritas (0 a 1, quanto mais perto de 1 mais errada a transcrição)
#Character Error Rate (CER): taxa de acerto dos caracteres transcritos (0 a 1, quanto mais perto de 1 mais errada a transcrição)

from jiwer import wer, cer

def validar_transcricoes(df_validado):
    df_validado['WER'] = df_validado.apply(lambda row: wer(row['sentence'], row['texto_transcrito_modelo']), axis=1)
    df_validado['CER'] = df_validado.apply(lambda row: cer(row['sentence'], row['texto_transcrito_modelo']), axis=1)
    return df_validado

df_validado = validar_transcricoes(df_concat)
df_validado.head(5)
# Out:
#                            path  \
# 0  common_voice_pt_37591374.mp3
# 1  common_voice_pt_37526011.mp3
# 2  common_voice_pt_37274519.mp3
# 3  common_voice_pt_32308715.mp3
# 4  common_voice_pt_32341511.mp3
#
#                                             sentence  count_caracteres  \
# 0  actínio, tório, protactínio, urânio, netúnio, ...               134
# 1  disfunção sexual, erétil, ejaculação precoce, ...               115
# 2  eletroafinidade, eletronegatividade, eletropos...               121
# 3                                               Cipó                 4
# 4                                               Iepê                 4
#
#                              texto_transcrito_modelo       WER       CER
# 0  actine otorio protactínio urânio Netuno ameríc...  1.000000  0.462687
# 1  disfunção sexual erétil ejaculação precoce vag...  0.583333  0.060870
# 2  eletroafinidade eletronegatividade eletroposit...  1.222222  0.099174
# 3                                               Cipó  0.000000  0.000000
# 4                                               Iepê  0.000000  0.000000

# %%
taxa_erro_média = df_validado['CER'][df_validado['CER']<1].mean()
print(f'A taxa de erros de caracteres média antes da normalização foi de {round(taxa_erro_média*100,2)}%')
# Out:
# A taxa de erros de caracteres média antes da normalização foi de 12.57%

# %% [markdown]
# ### **Validação após normalizar a transcrição do modelo com base em WER e CER (retirada de acentos)**

# %%
#Função para remover acentos das palavras
from unidecode import unidecode

def remover_acentos(palavra):
    return unidecode(palavra)

# %%
df_validado['dataset_normalizado'] = df_validado['sentence'].apply(remover_acentos)
df_validado['transcricao_normalizada'] = df_validado['texto_transcrito_modelo'].apply(remover_acentos)
df_validado.head(10)
# Out:
#                            path  \
# 0  common_voice_pt_37591374.mp3
# 1  common_voice_pt_37526011.mp3
# 2  common_voice_pt_37274519.mp3
# 3  common_voice_pt_32308715.mp3
# 4  common_voice_pt_32341511.mp3
# 5  common_voice_pt_35160648.mp3
# 6  common_voice_pt_35911777.mp3
# 7  common_voice_pt_32886098.mp3
# 8  common_voice_pt_36455648.mp3
# 9  common_voice_pt_30580984.mp3
#
#                                             sentence  count_caracteres  \
# 0  actínio, tório, protactínio, urânio, netúnio, ...               134
# 1  disfunção sexual, erétil, ejaculação precoce, ...               115
# 2  eletroafinidade, eletronegatividade, eletropos...               121
# 3                                               Cipó                 4
# 4                                               Iepê                 4
# 5                                                mês                 3
# 6                                                Eu?                 3
# 7  Mas barreiras também são encontradas em nossos...                99
# 8  Trabalhos posteriores foram realizados onde fo...               108
# 9  Trabalhos posteriores foram realizados onde fo...               108
#
#                              texto_transcrito_modelo       WER        CER  \
# 0  actine otorio protactínio urânio Netuno ameríc...  1.000000   0.462687
# 1  disfunção sexual erétil ejaculação precoce vag...  0.583333   0.060870
# 2  eletroafinidade eletronegatividade eletroposit...  1.222222   0.099174
# 3                                               Cipó  0.000000   0.000000
# 4                                               Iepê  0.000000   0.000000
# 5                                                mês  0.000000   0.000000
# 6                  Não foi possível entender o áudio  6.000000  10.666667
# 7  as barreiras também são encontradas em nossos ...  0.333333   0.040404
# 8  trabalhos posteriores foram realizados onde fo...  0.214286   0.046296
# 9  trabalhos posteriores foram realizados onde fo...  0.142857   0.018519
#
#                                  dataset_normalizado  \
# 0  actinio, torio, protactinio, uranio, netunio, ...
# 1  disfuncao sexual, eretil, ejaculacao precoce, ...
# 2  eletroafinidade, eletronegatividade, eletropos...
# 3                                               Cipo
# 4                                               Iepe
# 5                                                mes
# 6                                                Eu?
# 7  Mas barreiras tambem sao encontradas em nossos...
# 8  Trabalhos posteriores foram realizados onde fo...
# 9  Trabalhos posteriores foram realizados onde fo...
#
#                              transcricao_normalizada
# 0  actine otorio protactinio uranio Netuno americ...
# 1  disfuncao sexual eretil ejaculacao precoce vag...
# 2  eletroafinidade eletronegatividade eletroposit...
# 3                                               Cipo
# 4                                               Iepe
# 5                                                mes
# 6                  Nao foi possivel entender o audio
# 7  as barreiras tambem sao encontradas em nossos ...
# 8  trabalhos posteriores foram realizados onde fo...
# 9  trabalhos posteriores foram realizados onde fo...

# %%
def validar_transcricoes_normalizadas(df_validado):
    df_validado['WER_normalizado'] = df_validado.apply(lambda row: wer(row['dataset_normalizado'], row['transcricao_normalizada']), axis=1)
    df_validado['CER_normalizado'] = df_validado.apply(lambda row: cer(row['dataset_normalizado'], row['transcricao_normalizada']), axis=1)
    return df_validado

df_validado = validar_transcricoes_normalizadas(df_concat)
df_validado.head(5)
# Out:
#                            path  \
# 0  common_voice_pt_37591374.mp3
# 1  common_voice_pt_37526011.mp3
# 2  common_voice_pt_37274519.mp3
# 3  common_voice_pt_32308715.mp3
# 4  common_voice_pt_32341511.mp3
#
#                                             sentence  count_caracteres  \
# 0  actínio, tório, protactínio, urânio, netúnio, ...               134
# 1  disfunção sexual, erétil, ejaculação precoce, ...               115
# 2  eletroafinidade, eletronegatividade, eletropos...               121
# 3                                               Cipó                 4
# 4                                               Iepê                 4
#
#                              texto_transcrito_modelo       WER       CER  \
# 0  actine otorio protactínio urânio Netuno ameríc...  1.000000  0.462687
# 1  disfunção sexual erétil ejaculação precoce vag...  0.583333  0.060870
# 2  eletroafinidade eletronegatividade eletroposit...  1.222222  0.099174
# 3                                               Cipó  0.000000  0.000000
# 4                                               Iepê  0.000000  0.000000
#
#                                  dataset_normalizado  \
# 0  actinio, torio, protactinio, uranio, netunio, ...
# 1  disfuncao sexual, eretil, ejaculacao precoce, ...
# 2  eletroafinidade, eletronegatividade, eletropos...
# 3                                               Cipo
# 4                                               Iepe
#
#                              transcricao_normalizada  WER_normalizado  \
# 0  actine otorio protactinio uranio Netuno americ...         1.000000
# 1  disfuncao sexual eretil ejaculacao precoce vag...         0.583333
# 2  eletroafinidade eletronegatividade eletroposit...         1.222222
# 3                                               Cipo         0.000000
# 4                                               Iepe         0.000000
#
#    CER_normalizado
# 0         0.447761
# 1         0.060870
# 2         0.099174
# 3         0.000000
# 4         0.000000

# %%
#Gráfico para visualizar as validações por caracteres das transcrições normalizadas
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

#Primeiro gráfico: Validação por caracteres
sns.histplot(df_validado['CER_normalizado'][df_validado['CER_normalizado']<1], bins=10, ax=axs[0])
axs[0].set_title('Validação por caracteres das transcrições normalizadas')
axs[0].set_ylabel('Quantidades de transcrições')
axs[0].set_xlabel('Resultado da validação: Mais perto de 0, boa transcrição')

#Segundo gráfico
sns.histplot(df_validado['WER_normalizado'][df_validado['WER_normalizado']<1], bins=10, ax=axs[1])
axs[1].set_title('Validação por palavras das transcrições normalizadas')
axs[1].set_ylabel('Quantidades de transcrições')
axs[1].set_xlabel('Resultado da validação: Mais perto de 0, boa transcrição')
# Out:
# Text(0.5, 0, 'Resultado da validação: Mais perto de 0, boa transcrição')
